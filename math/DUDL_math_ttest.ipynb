# %% [markdown]
# # COURSE: A deep understanding of deep learning
# ## SECTION: Math prerequisites
# ### LECTURE: The t-test
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/deeplearning_x/?couponCode=202401

# %% [markdown]
# # My Notes

# %% [markdown]
# ## What is T-Test?

# %% [markdown]
# The t-test is a statistical hypothesis test used to compare the means of two groups or datasets to determine if the difference between them is statistically significant. In deep learning, t-tests are often applied to evaluate model performance, compare algorithms, or assess the impact of changes in hyperparameters or datasets.

# %% [markdown]
# ### Types of T-tests

# %% [markdown]
# 1. One-sample t-test:
#     * Compares the mean of a single sample to a known value (e.g., population mean).
#     * Example: Checking if the accuracy of a model is significantly different from a baseline value.
# 1. Two-sample t-test:
#     * Compares the means of two independent samples.
#     * Example: Comparing the performance of two models trained on different datasets.
# 1. Paired t-test:
#     * Compares two related samples, such as before-and-after measurements or results from two models tested on the same dataset.
#     * Example: Comparing the accuracy of two classifiers on the same test set.

# %% [markdown]
# ### t-test in Deep Learning

# %% [markdown]
# In deep learning, t-tests can be used for:
# * Model comparison: To determine if one model performs significantly better than another.
# * Hyperparameter tuning: To test if changes in hyperparameters lead to statistically significant performance improvements.
# * Feature selection: To evaluate whether adding or removing features significantly affects model performance.

# %% [markdown]
# # Course Content: Exercises

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt

# NEW!
import scipy.stats as stats

# %% [markdown]
# Note: `mu1` and `mu2` below are used to control the `mean` values of the two data sets. you can alter their values to play with scenarios where two data sets have similar or very different means, and compare the outcome of the t-tests.

# %%
# parameters
n1 = 30   # samples in dataset 1
n2 = 40   # ...and 2
mu1 = 1   # population mean in dataset 1
mu2 = 2   # population mean in dataset 2

# generate the data
data1 = mu1 + np.random.randn(n1)
data2 = mu2 + np.random.randn(n2)



# plot them
plt.plot(np.zeros(n1),data1,'ro',markerfacecolor='w',markersize=7)
plt.plot(np.ones(n2), data2,'bs',markerfacecolor='w',markersize=7)
plt.xlim([-1,2])
plt.xticks([0,1],labels=['Group 1','Group 2'])
plt.show()

# %%
# t-test via stats package

# _ind = independent samples
t,p = stats.ttest_ind(data1,data2)
print(t)
print(p)
# Out:
# -0.13931356237314863
# 0.889614161399878

# %%
# common way to show t-test results in a plot
fig = plt.figure(figsize=(10,4))
plt.rcParams.update({'font.size':12}) # change the font size

plt.plot(0+np.random.randn(n1)/15, data1, 'ro',markerfacecolor='w',markersize=7)
plt.plot(1+np.random.randn(n2)/15, data2, 'bs',markerfacecolor='w',markersize=7)
plt.xlim([-1,2])
plt.xticks([0,1],labels=['Group 1','Group 2'])

# set the title to include the t-value and p-value
plt.title(f't = {t:.2f}, p={p:.3f}')

plt.show()
